# %%
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/frontiers.csv")
testFrontier = data.loc[data.Frontier == "test"]
x = testFrontier["Restoration (Ha-yr)"]
y = testFrontier["Employment (m3 eucalyptus)"]
z = testFrontier["Income (USD)"]

# %%
fig = plt.figure()
# Out:
#    Frontier  SolutionIndex  Restoration (Ha-yr)  Employment (m3 eucalyptus)  \
# 0      test              0           50540.2395                  259677.094
# 1      test              1           50604.4655                  278147.729
# 2      test             10           50134.8495                  336014.098
# 3      test             11           45297.8110                  289317.164
# 4      test             12           49921.5195                  335133.183
# 5      test             13           49361.9310                  315813.629
# 6      test             14           48881.0100                  334637.597
# 7      test             15           47730.6100                  307481.343
# 8      test             16           47046.7440                  251453.071
# 9      test             17           45730.1725                  272361.188
# 10     test             20           43588.2315                  254373.352
# ...
