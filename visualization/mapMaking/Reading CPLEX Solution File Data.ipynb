# %% [markdown]
# #Read in CPLEX Solution files
# And make data to style maps in the multi-objective visualization

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import os

# %%
frontiers = ["NONE", "Ensemble_rcp45", "Ensemble_rcp85"]
objNames = ["FireHazardIncrease","MinOwlHabitat","MaxSediment"]
# allSolutions is the data file fed to the visualization to create the scatterplots, parallel coords, etc.
allSolutionsRow = {'Frontier': [],
                'SolutionIndex': [],
                'Increase in fire hazard': [],
                'Min NSO habitat': [],
                'Max Sediment delivery (t)': []}
allSolutions = pd.DataFrame(allSolutionsRow)

# %%
# make empty datframe for stand-level storage of initial-final values for the objectives
initFinalStandVals = {'Stand': [],
                      'TimePeriod': [],
                      'Objective': [],
                      'Value': []}
initFinalStandVals = pd.DataFrame(initFinalStandVals)
initfinalfire = pd.read_csv("initialFinalStandFireData.csv")
initfinalowl = pd.read_csv("initialFinalStandOwlData.csv")
# list of objectives for which we will show initial and final statistics for
initFinalObjs = ["FireHazardIncrease","MinOwlHabitat"]

# %%
# make empty dataframe for storage of data for map coloring
valsForPaintingStandsInMapsEmpty = {'Frontier': [],
                               'SolutionIndex': [],
                               'MapColumn': [],
                               'Stand': [],
                               'Objective': [],
                               'Value': []}
valsForPaintingStandsInMaps = pd.DataFrame(valsForPaintingStandsInMapsEmpty)
#solutionsAlreadyInMapFile = [str(int(i)) for i in pd.read_csv("mapMakingData_1_upTo27.csv")["SolutionIndex"].unique().tolist()]
#solutionsAlreadyInMapFile
# Out:
# ['0',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '2',
#  '20',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '26',
#  '27',
#  '28']

# %%
def parseSolutionFiles():
    global allSolutions
    global valsForPaintingStandsInMaps
    # each solution will have a line in the allSolutions file
    newAllSolutionsRow = allSolutionsRow
    newAllSolutionsRow["Frontier"] = frontier
    # It will also have dataframe of length mapcols(4)*stands(303)*initFinalObjs(2)
    standMapVals = valsForPaintingStandsInMapsEmpty
    standMapVals["Frontier"] = frontier
    # get the solution index on the frontier, add it to our new row in the allSolutions file
    solIndex = solFile[solFile.rfind("_")+1:solFile.rfind(".")]
    standMapVals["SolutionIndex"] = solIndex
    newAllSolutionsRow["SolutionIndex"] = solIndex
    # rename the file accordingly
    newName = frontier + "_" + solIndex + ".sol"
    os.rename(solDir + solFile, solDir + newName)
    # parse the solution file
    print ("----------")
    print ("reading file " + newName + "...")
    solTree = ET.parse(solDir + newName)
    print (newName + " read successfully")
    cpxSol = solTree.getroot()
    # get important variable values: x_i_r's, and objectives
    numvarsSet = 0 # break loop when it hits 306
    numobjvarsSet = 0
    for variable in cpxSol.iter("variable"):
        varname = variable.get("name")
        firstCharOfName = varname[0].lower()
        if varname in objNames:
            print ("handling objective variable " + varname)
            varval = float(variable.get("value"))
            # store values in the new entry in the allSolutions row
            if varname[0:3] == "Fir":
                newAllSolutionsRow["Increase in fire hazard"] = varval
                numvarsSet += 1
                numobjvarsSet += 1
            elif varname[0:3] == "Min":
                newAllSolutionsRow["Min NSO habitat"] = varval
                numvarsSet += 1
                numobjvarsSet += 1
            else:
                newAllSolutionsRow["Max Sediment delivery (t)"] = varval
                numvarsSet += 1
                numobjvarsSet += 1
        # if all objective values have been recorded, determine if the solution is dominated
        fireobjval = newAllSolutionsRow["Increase in fire hazard"]
        nsoobjval = newAllSolutionsRow["Min NSO habitat"]
        sedobjval = newAllSolutionsRow["Max Sediment delivery (t)"]
        if numobjvarsSet == 3:
            # check dominated
            for idx,row in allSolutions.iterrows():
                checkvalfire = row["Increase in fire hazard"]
                checkvalowl = row["Min NSO habitat"]
                checkvalsed = row["Max Sediment delivery (t)"]
                if checkvalfire <= fireobjval and checkvalowl >= nsoobjval and checkvalsed <= sedobjval:
                    return
        if firstCharOfName == "x":
            varval = int(variable.get("value"))
            if varval > 0: # gives the stand's prescription
                print ("handling nonzero stand assignment variable " + varname)
                stand = int(varname[varname.index("_")+1:varname.rfind("_")])
                trtSched = int(varname[varname.rfind("_")+1])
                standMapVals["Stand"] = stand
                for mapcol in range(4):
                    standMapVals["MapColumn"] = mapcol
                    for obj in initFinalObjs:
                        standMapVals["Objective"] = obj
                        if mapcol == 0: # then we need to describe the initial state
                            if obj[0] == "F": # if doing the fire objective
                                standMapVals["Value"] = initfinalfire.loc[initfinalfire["stand"] == stand].loc[
                                    initfinalfire["climateScenario"] == frontier]["initial"].tolist()[0]
                            else: #doing the owl objective
                                if (initfinalowl.loc[initfinalowl["stand"] == stand].loc[
                                    initfinalowl["climateScenario"] == frontier]["initial"].tolist()[0]): # if true, assign value 1
                                    standMapVals["Value"] = 1
                                else:  # otherwise, assign value 0
                                    standMapVals["Value"] = 0
                        elif mapcol == 3: # then we need to describe the final state
                            if obj[0] == "F": # if doing the fire objective
                                standMapVals["Value"] = initfinalfire.loc[initfinalfire["stand"] == stand].loc[
                                    initfinalfire["climateScenario"] == frontier].ix[:,trtSched+3].tolist()[0]
                            else: #doing the owl objective
                                if (initfinalowl.loc[initfinalowl["stand"] == stand].loc[
                                    initfinalowl["climateScenario"] == frontier].ix[:,trtSched+3].tolist()[0]): # if true, assign value 1
                                    standMapVals["Value"] = 1
                                else:  # otherwise, assign value 0
                                    standMapVals["Value"] = 0
                        elif mapcol == 1: # looking at first time period
                            if trtSched == 1 or trtSched == 3: # we will treat in the first
                                standMapVals["Value"] = 1
                            else: #no trtment in the first period
                                standMapVals["Value"] = 0
                        else: # looking at second time period
                            if trtSched == 2 or trtSched == 3: # we will treat in the second
                                standMapVals["Value"] = 1
                            else:
                                standMapVals["Value"] = 0
                        valsForPaintingStandsInMaps = valsForPaintingStandsInMaps.append(standMapVals, ignore_index=True)
                        valsForPaintingStandsInMaps.to_csv("mapMakingData.csv", index=None)
                numvarsSet += 1
        if numvarsSet >= 306:
            print "All stand and objective "
            break
    # append new solution row to the allSolutions df
    allSolutions = allSolutions.append(newAllSolutionsRow, ignore_index=True)
    allSolutions.to_csv("climateChange_AllSolutions_primary.csv", index=None)
    return

# %%
def parseSolutionFilesButOnlyGetObjectiveData():
    global allSolutions
    # each solution will have a line in the allSolutions file
    newAllSolutionsRow = allSolutionsRow
    newAllSolutionsRow["Frontier"] = frontier
    # get the solution index on the frontier, add it to our new row in the allSolutions file
    solIndex = solFile[solFile.rfind("_")+1:solFile.rfind(".")]
    newAllSolutionsRow["SolutionIndex"] = solIndex
    # rename the file accordingly
    newName = frontier + "_" + solIndex + ".sol"
    os.rename(solDir + solFile, solDir + newName)
    # parse the solution file
    print ("----------")
    print ("reading file " + newName + "...")
    solTree = ET.parse(solDir + newName)
    print (newName + " read successfully")
    cpxSol = solTree.getroot()
    # get important variable values: x_i_r's, and objectives
    numvarsSet = 0 # break loop when it hits 306
    numobjvarsSet = 0
    for variable in cpxSol.iter("variable"):
        varname = variable.get("name")
        firstCharOfName = varname[0].lower()
        if varname in objNames:
            print ("handling objective variable " + varname)
            varval = float(variable.get("value"))
            # store values in the new entry in the allSolutions row
            if varname[0:3] == "Fir":
                newAllSolutionsRow["Increase in fire hazard"] = varval
                numvarsSet += 1
                numobjvarsSet += 1
            elif varname[0:3] == "Min":
                newAllSolutionsRow["Min NSO habitat"] = varval
                numvarsSet += 1
                numobjvarsSet += 1
            else:
                newAllSolutionsRow["Max Sediment delivery (t)"] = varval
                numvarsSet += 1
                numobjvarsSet += 1
        # if all objective values have been recorded, determine if the solution is dominated
        fireobjval = newAllSolutionsRow["Increase in fire hazard"]
        nsoobjval = newAllSolutionsRow["Min NSO habitat"]
        sedobjval = newAllSolutionsRow["Max Sediment delivery (t)"]
        if numobjvarsSet == 3:
            # check dominated
            for idx,row in allSolutions.iterrows():
                checkvalfire = row["Increase in fire hazard"]
                checkvalowl = row["Min NSO habitat"]
                checkvalsed = row["Max Sediment delivery (t)"]
                if checkvalfire <= fireobjval and checkvalowl >= nsoobjval and checkvalsed <= sedobjval:
                    return
            # then since it's not dominated, print the new line and return
            # append new solution row to the allSolutions df
            allSolutions = allSolutions.append(newAllSolutionsRow, ignore_index=True)
            allSolutions = allSolutions[["Frontier","SolutionIndex","Increase in fire hazard","Max Sediment delivery (t)","Min NSO habitat"]]
            allSolutions.to_csv("climateChange_AllSolutions_primary.csv", index=None)
            return

# %%
def parseSolutionFilesButJustMapFileStuff():
    global valsForPaintingStandsInMaps
    # It will have dataframe of length mapcols(4)*stands(303)*initFinalObjs(2)
    standMapVals = valsForPaintingStandsInMapsEmpty
    standMapVals["Frontier"] = frontier
    # get the solution index on the frontier
    solIndex = solFile[solFile.rfind("_")+1:solFile.rfind(".")]
    if solIndex != '28':
        print "not 28. terminating"
        return
    print solIndex
    standMapVals["SolutionIndex"] = solIndex
    # rename the file accordingly
    newName = frontier + "_" + solIndex + ".sol"
    os.rename(solDir + solFile, solDir + newName)
    # parse the solution file
    print ("----------")
    print ("reading file " + newName + "...")
    solTree = ET.parse(solDir + newName)
    print (newName + " read successfully")
    cpxSol = solTree.getroot()
    # get important variable values: x_i_r's, and objectives
    numvarsSet = 0 # break loop when it hits 303
    numobjvarsSet = 0
    for variable in cpxSol.iter("variable"):
        varname = variable.get("name")
        firstCharOfName = varname[0].lower()
        if firstCharOfName == "x":
            varval = int(round(float(variable.get("value"))))
            if varval > 0: # gives the stand's prescription
                print ("handling nonzero stand assignment variable " + varname)
                stand = int(varname[varname.index("_")+1:varname.rfind("_")])
                trtSched = int(varname[varname.rfind("_")+1])
                standMapVals["Stand"] = stand
                for mapcol in range(4):
                    standMapVals["MapColumn"] = mapcol
                    for obj in initFinalObjs:
                        standMapVals["Objective"] = obj
                        if mapcol == 0: # then we need to describe the initial state
                            if obj[0] == "F": # if doing the fire objective
                                standMapVals["Value"] = initfinalfire.loc[initfinalfire["stand"] == stand].loc[
                                    initfinalfire["climateScenario"] == frontier]["initial"].tolist()[0]
                            else: #doing the owl objective
                                if (initfinalowl.loc[initfinalowl["stand"] == stand].loc[
                                    initfinalowl["climateScenario"] == frontier]["initial"].tolist()[0]): # if true, assign value 1
                                    standMapVals["Value"] = 1
                                else:  # otherwise, assign value 0
                                    standMapVals["Value"] = 0
                        elif mapcol == 3: # then we need to describe the final state
                            if obj[0] == "F": # if doing the fire objective
                                standMapVals["Value"] = initfinalfire.loc[initfinalfire["stand"] == stand].loc[
                                    initfinalfire["climateScenario"] == frontier].ix[:,trtSched+3].tolist()[0]
                            else: #doing the owl objective
                                if (initfinalowl.loc[initfinalowl["stand"] == stand].loc[
                                    initfinalowl["climateScenario"] == frontier].ix[:,trtSched+3].tolist()[0]): # if true, assign value 1
                                    standMapVals["Value"] = 1
                                else:  # otherwise, assign value 0
                                    standMapVals["Value"] = 0
                        elif mapcol == 1: # looking at first time period
                            if trtSched == 1 or trtSched == 3: # we will treat in the first
                                standMapVals["Value"] = 1
                            else: #no trtment in the first period
                                standMapVals["Value"] = 0
                        else: # looking at second time period
                            if trtSched == 2 or trtSched == 3: # we will treat in the second
                                standMapVals["Value"] = 1
                            else:
                                standMapVals["Value"] = 0
                        valsForPaintingStandsInMaps = valsForPaintingStandsInMaps.append(standMapVals, ignore_index=True)
                numvarsSet += 1
        if numvarsSet >= 303:
            print "All stands in this solution accounted for. Reprinting CSV and moving on."
            valsForPaintingStandsInMaps.to_csv("mapMakingData_only28.csv", index=None)
            break
    return

# %%
for frontier in frontiers:
    print frontier
    if frontier.startswith("E"): # temp break while trialing the below
        break
    # get list of solution files from this folder
    solFiles = []
    solDir = "solutionFiles/" + frontier + "/"
    for (dirpath, dirnames, filenames) in os.walk(solDir):
        solFiles.extend(filenames)
    # for each solution...
    for solFile in solFiles:
        parseSolutionFilesButJustMapFileStuff()
# Out:
# NONE
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# 28
# ----------
# reading file NONE_28.sol...
# NONE_28.sol read successfully
# handling nonzero stand assignment variable x_0_1
# handling nonzero stand assignment variable x_1_2
# handling nonzero stand assignment variable x_2_1
# handling nonzero stand assignment variable x_3_1
# handling nonzero stand assignment variable x_4_2
# handling nonzero stand assignment variable x_5_0
# handling nonzero stand assignment variable x_6_3
# handling nonzero stand assignment variable x_7_0
# handling nonzero stand assignment variable x_8_2
# handling nonzero stand assignment variable x_9_3
# handling nonzero stand assignment variable x_10_1
# handling nonzero stand assignment variable x_11_1
# handling nonzero stand assignment variable x_12_3
# handling nonzero stand assignment variable x_13_0
# handling nonzero stand assignment variable x_14_1
# handling nonzero stand assignment variable x_15_2
# handling nonzero stand assignment variable x_16_1
# handling nonzero stand assignment variable x_17_0
# handling nonzero stand assignment variable x_18_2
# handling nonzero stand assignment variable x_19_2
# handling nonzero stand assignment variable x_20_2
# handling nonzero stand assignment variable x_21_1
# handling nonzero stand assignment variable x_22_0
# handling nonzero stand assignment variable x_23_2
# handling nonzero stand assignment variable x_24_2
# handling nonzero stand assignment variable x_25_0
# handling nonzero stand assignment variable x_26_0
# handling nonzero stand assignment variable x_27_0
# handling nonzero stand assignment variable x_28_1
# handling nonzero stand assignment variable x_29_1
# handling nonzero stand assignment variable x_30_0
# handling nonzero stand assignment variable x_31_0
# handling nonzero stand assignment variable x_32_2
# handling nonzero stand assignment variable x_33_0
# handling nonzero stand assignment variable x_34_2
# handling nonzero stand assignment variable x_35_1
# handling nonzero stand assignment variable x_36_3
# handling nonzero stand assignment variable x_37_3
# handling nonzero stand assignment variable x_38_0
# handling nonzero stand assignment variable x_39_2
# handling nonzero stand assignment variable x_40_1
# handling nonzero stand assignment variable x_41_1
# handling nonzero stand assignment variable x_42_3
# handling nonzero stand assignment variable x_43_1
# handling nonzero stand assignment variable x_44_0
# handling nonzero stand assignment variable x_45_1
# handling nonzero stand assignment variable x_46_0
# handling nonzero stand assignment variable x_47_1
# handling nonzero stand assignment variable x_48_0
# handling nonzero stand assignment variable x_49_2
# handling nonzero stand assignment variable x_50_2
# handling nonzero stand assignment variable x_51_0
# handling nonzero stand assignment variable x_52_1
# handling nonzero stand assignment variable x_53_1
# handling nonzero stand assignment variable x_54_1
# handling nonzero stand assignment variable x_55_0
# handling nonzero stand assignment variable x_56_0
# handling nonzero stand assignment variable x_57_1
# handling nonzero stand assignment variable x_58_1
# handling nonzero stand assignment variable x_59_2
# handling nonzero stand assignment variable x_60_1
# handling nonzero stand assignment variable x_61_2
# handling nonzero stand assignment variable x_62_2
# handling nonzero stand assignment variable x_63_2
# handling nonzero stand assignment variable x_64_0
# handling nonzero stand assignment variable x_65_0
# handling nonzero stand assignment variable x_66_1
# handling nonzero stand assignment variable x_67_0
# handling nonzero stand assignment variable x_68_0
# handling nonzero stand assignment variable x_69_0
# handling nonzero stand assignment variable x_70_3
# handling nonzero stand assignment variable x_71_0
# handling nonzero stand assignment variable x_72_0
# handling nonzero stand assignment variable x_73_1
# handling nonzero stand assignment variable x_74_0
# handling nonzero stand assignment variable x_75_0
# handling nonzero stand assignment variable x_76_0
# handling nonzero stand assignment variable x_77_0
# handling nonzero stand assignment variable x_78_1
# handling nonzero stand assignment variable x_79_2
# handling nonzero stand assignment variable x_80_1
# handling nonzero stand assignment variable x_81_2
# handling nonzero stand assignment variable x_82_2
# handling nonzero stand assignment variable x_83_2
# handling nonzero stand assignment variable x_84_2
# handling nonzero stand assignment variable x_85_2
# handling nonzero stand assignment variable x_86_0
# handling nonzero stand assignment variable x_87_1
# handling nonzero stand assignment variable x_88_0
# handling nonzero stand assignment variable x_89_1
# handling nonzero stand assignment variable x_90_2
# handling nonzero stand assignment variable x_91_2
# handling nonzero stand assignment variable x_92_2
# handling nonzero stand assignment variable x_93_0
# handling nonzero stand assignment variable x_94_1
# handling nonzero stand assignment variable x_95_1
# handling nonzero stand assignment variable x_96_1
# handling nonzero stand assignment variable x_97_2
# handling nonzero stand assignment variable x_98_2
# handling nonzero stand assignment variable x_99_1
# handling nonzero stand assignment variable x_100_1
# handling nonzero stand assignment variable x_101_1
# handling nonzero stand assignment variable x_102_1
# handling nonzero stand assignment variable x_103_1
# handling nonzero stand assignment variable x_104_1
# handling nonzero stand assignment variable x_105_3
# handling nonzero stand assignment variable x_106_2
# handling nonzero stand assignment variable x_107_1
# handling nonzero stand assignment variable x_108_2
# handling nonzero stand assignment variable x_109_2
# handling nonzero stand assignment variable x_110_2
# handling nonzero stand assignment variable x_111_2
# handling nonzero stand assignment variable x_112_1
# handling nonzero stand assignment variable x_113_2
# handling nonzero stand assignment variable x_114_0
# handling nonzero stand assignment variable x_115_1
# handling nonzero stand assignment variable x_116_0
# handling nonzero stand assignment variable x_117_2
# handling nonzero stand assignment variable x_118_2
# handling nonzero stand assignment variable x_119_1
# handling nonzero stand assignment variable x_120_1
# handling nonzero stand assignment variable x_121_0
# handling nonzero stand assignment variable x_122_2
# handling nonzero stand assignment variable x_123_2
# handling nonzero stand assignment variable x_124_1
# handling nonzero stand assignment variable x_125_1
# handling nonzero stand assignment variable x_126_0
# handling nonzero stand assignment variable x_127_0
# handling nonzero stand assignment variable x_128_2
# handling nonzero stand assignment variable x_129_1
# handling nonzero stand assignment variable x_130_1
# handling nonzero stand assignment variable x_131_0
# handling nonzero stand assignment variable x_132_0
# handling nonzero stand assignment variable x_133_0
# handling nonzero stand assignment variable x_134_1
# handling nonzero stand assignment variable x_135_0
# handling nonzero stand assignment variable x_136_1
# handling nonzero stand assignment variable x_137_0
# handling nonzero stand assignment variable x_138_0
# handling nonzero stand assignment variable x_139_0
# handling nonzero stand assignment variable x_140_0
# handling nonzero stand assignment variable x_141_0
# handling nonzero stand assignment variable x_142_1
# handling nonzero stand assignment variable x_143_0
# handling nonzero stand assignment variable x_144_0
# handling nonzero stand assignment variable x_145_1
# handling nonzero stand assignment variable x_146_0
# handling nonzero stand assignment variable x_147_1
# handling nonzero stand assignment variable x_148_1
# handling nonzero stand assignment variable x_149_2
# handling nonzero stand assignment variable x_150_1
# handling nonzero stand assignment variable x_151_2
# handling nonzero stand assignment variable x_152_2
# handling nonzero stand assignment variable x_153_2
# handling nonzero stand assignment variable x_154_2
# handling nonzero stand assignment variable x_155_1
# handling nonzero stand assignment variable x_156_2
# handling nonzero stand assignment variable x_157_0
# handling nonzero stand assignment variable x_158_1
# handling nonzero stand assignment variable x_159_2
# handling nonzero stand assignment variable x_160_2
# handling nonzero stand assignment variable x_161_2
# handling nonzero stand assignment variable x_162_1
# handling nonzero stand assignment variable x_163_1
# handling nonzero stand assignment variable x_164_0
# handling nonzero stand assignment variable x_165_0
# handling nonzero stand assignment variable x_166_3
# handling nonzero stand assignment variable x_167_0
# handling nonzero stand assignment variable x_168_0
# handling nonzero stand assignment variable x_169_3
# handling nonzero stand assignment variable x_170_1
# handling nonzero stand assignment variable x_171_2
# handling nonzero stand assignment variable x_172_0
# handling nonzero stand assignment variable x_173_0
# handling nonzero stand assignment variable x_174_0
# handling nonzero stand assignment variable x_175_2
# handling nonzero stand assignment variable x_176_0
# handling nonzero stand assignment variable x_177_0
# handling nonzero stand assignment variable x_178_0
# handling nonzero stand assignment variable x_179_0
# handling nonzero stand assignment variable x_180_1
# handling nonzero stand assignment variable x_181_0
# handling nonzero stand assignment variable x_182_0
# handling nonzero stand assignment variable x_183_0
# handling nonzero stand assignment variable x_184_1
# handling nonzero stand assignment variable x_185_0
# handling nonzero stand assignment variable x_186_1
# handling nonzero stand assignment variable x_187_0
# handling nonzero stand assignment variable x_188_1
# handling nonzero stand assignment variable x_189_0
# handling nonzero stand assignment variable x_190_1
# handling nonzero stand assignment variable x_191_0
# handling nonzero stand assignment variable x_192_1
# handling nonzero stand assignment variable x_193_1
# handling nonzero stand assignment variable x_194_0
# handling nonzero stand assignment variable x_195_1
# handling nonzero stand assignment variable x_196_2
# handling nonzero stand assignment variable x_197_1
# handling nonzero stand assignment variable x_198_1
# handling nonzero stand assignment variable x_199_1
# handling nonzero stand assignment variable x_200_0
# handling nonzero stand assignment variable x_201_2
# handling nonzero stand assignment variable x_202_1
# handling nonzero stand assignment variable x_203_3
# handling nonzero stand assignment variable x_204_2
# handling nonzero stand assignment variable x_205_1
# handling nonzero stand assignment variable x_206_1
# handling nonzero stand assignment variable x_207_0
# handling nonzero stand assignment variable x_208_2
# handling nonzero stand assignment variable x_209_0
# handling nonzero stand assignment variable x_210_2
# handling nonzero stand assignment variable x_211_1
# handling nonzero stand assignment variable x_212_1
# handling nonzero stand assignment variable x_213_0
# handling nonzero stand assignment variable x_214_1
# handling nonzero stand assignment variable x_215_2
# handling nonzero stand assignment variable x_216_1
# handling nonzero stand assignment variable x_217_1
# handling nonzero stand assignment variable x_218_0
# handling nonzero stand assignment variable x_219_1
# handling nonzero stand assignment variable x_220_0
# handling nonzero stand assignment variable x_221_1
# handling nonzero stand assignment variable x_222_0
# handling nonzero stand assignment variable x_223_0
# handling nonzero stand assignment variable x_224_1
# handling nonzero stand assignment variable x_225_2
# handling nonzero stand assignment variable x_226_2
# handling nonzero stand assignment variable x_227_2
# handling nonzero stand assignment variable x_228_1
# handling nonzero stand assignment variable x_229_1
# handling nonzero stand assignment variable x_230_1
# handling nonzero stand assignment variable x_231_0
# handling nonzero stand assignment variable x_232_0
# handling nonzero stand assignment variable x_233_0
# handling nonzero stand assignment variable x_234_0
# handling nonzero stand assignment variable x_235_0
# handling nonzero stand assignment variable x_236_0
# handling nonzero stand assignment variable x_237_0
# handling nonzero stand assignment variable x_238_0
# handling nonzero stand assignment variable x_239_0
# handling nonzero stand assignment variable x_240_0
# handling nonzero stand assignment variable x_241_0
# handling nonzero stand assignment variable x_242_0
# handling nonzero stand assignment variable x_243_0
# handling nonzero stand assignment variable x_244_0
# handling nonzero stand assignment variable x_245_0
# handling nonzero stand assignment variable x_246_0
# handling nonzero stand assignment variable x_247_0
# handling nonzero stand assignment variable x_248_0
# handling nonzero stand assignment variable x_249_0
# handling nonzero stand assignment variable x_250_0
# handling nonzero stand assignment variable x_251_0
# handling nonzero stand assignment variable x_252_0
# handling nonzero stand assignment variable x_253_0
# handling nonzero stand assignment variable x_254_0
# handling nonzero stand assignment variable x_255_1
# handling nonzero stand assignment variable x_256_2
# handling nonzero stand assignment variable x_257_0
# handling nonzero stand assignment variable x_258_0
# handling nonzero stand assignment variable x_259_0
# handling nonzero stand assignment variable x_260_0
# handling nonzero stand assignment variable x_261_2
# handling nonzero stand assignment variable x_262_1
# handling nonzero stand assignment variable x_263_0
# handling nonzero stand assignment variable x_264_2
# handling nonzero stand assignment variable x_265_0
# handling nonzero stand assignment variable x_266_2
# handling nonzero stand assignment variable x_267_0
# handling nonzero stand assignment variable x_268_2
# handling nonzero stand assignment variable x_269_0
# handling nonzero stand assignment variable x_270_2
# handling nonzero stand assignment variable x_271_0
# handling nonzero stand assignment variable x_272_0
# handling nonzero stand assignment variable x_273_3
# handling nonzero stand assignment variable x_274_1
# handling nonzero stand assignment variable x_275_0
# handling nonzero stand assignment variable x_276_0
# handling nonzero stand assignment variable x_277_2
# handling nonzero stand assignment variable x_278_0
# handling nonzero stand assignment variable x_279_0
# handling nonzero stand assignment variable x_280_1
# handling nonzero stand assignment variable x_281_0
# handling nonzero stand assignment variable x_282_2
# handling nonzero stand assignment variable x_283_0
# handling nonzero stand assignment variable x_284_1
# handling nonzero stand assignment variable x_285_2
# handling nonzero stand assignment variable x_286_0
# handling nonzero stand assignment variable x_287_1
# handling nonzero stand assignment variable x_288_2
# handling nonzero stand assignment variable x_289_1
# handling nonzero stand assignment variable x_290_0
# handling nonzero stand assignment variable x_291_2
# handling nonzero stand assignment variable x_292_0
# handling nonzero stand assignment variable x_293_0
# handling nonzero stand assignment variable x_294_2
# handling nonzero stand assignment variable x_295_1
# handling nonzero stand assignment variable x_296_0
# handling nonzero stand assignment variable x_297_0
# handling nonzero stand assignment variable x_298_1
# handling nonzero stand assignment variable x_299_2
# handling nonzero stand assignment variable x_300_2
# handling nonzero stand assignment variable x_301_1
# handling nonzero stand assignment variable x_302_1
# All stands in this solution accounted for. Reprinting CSV and moving on.
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# not 28. terminating
# Ensemble_rcp45

# %%
#objNames.index("MinOwlHabitat")
#allSolutionsRow["Increase in fire hazard"] = 12
#initfinalfire.loc[initfinalfire["stand"] == 1].loc[initfinalfire["climateScenario"] == "NONE"].ix[:,trtSched+3].tolist()[0]
#domsoltester = pd.read_csv("../../visualization/data/frontiers.csv")
#domsoltester = domsoltester.append(domsoltester.ix[0], ignore_index=True)
#o1val = domsoltester.ix[0,2]
#o2val = domsoltester.ix[0,3]
#o3val = domsoltester.ix[0,4]
#ovals = [o1val,o2val,o3val]
#for idx,row in domsoltester.iterrows():
#    checkval1 = row[2]
#    checkval2 = row[3]
#    checkval3 = row[4]
#    if checkval1 > 
#    print checkval1
#valsForPaintingStandsInMaps
allmapdata = pd.read_csv("mapMakingData_all.csv")
allmapdata["MapColumn"] = allmapdata["MapColumn"].astype(int)
allmapdata["SolutionIndex"] = allmapdata["SolutionIndex"].astype(int)
allmapdata["Stand"] = allmapdata["Stand"].astype(int)
allmapdata["Frontier"] = "NONE"
# There are some issues in the values column. Fixing them now.
# Determined that the NaNs are from stands that were not simulated (not forested)
# Their NaN values can be replaced with 0s
allmapdata["Value"] = allmapdata["Value"].fillna(0)
allmapdata.to_csv("mapMakingData_noneOnly_final.csv", index=None)

# %%
#int(round(float('1.0000000000004092')))
#tdf = allmapdata
#tdf.ix[index[0],"Frontier"] = "test!"
#min(tdf["Stand"].unique().tolist())
initfinalfire.loc[initfinalfire["stand"] == 249]
# Out:
#      stand climateScenario  initial  none  first  second  both
# 747    249            NONE        0     0      0       0     0
# 748    249  Ensemble_rcp45        0     0      0       0     0
# 749    249  Ensemble_rcp85        0     0      0       0     0

# %%
# output datafile should ideally be something like:
# frontier | solnNum | Map Col (intial, first period, second period, end) | siteNum | value (to determine coloring)
# if map column is first or last, then color scheme is different than if it's just during the middle
# first/last show some quantitative variable on each stand
# middle show binary (yes treated or no treated)
# should be able to sniff out which color scheme to do based on the row's value for map col
